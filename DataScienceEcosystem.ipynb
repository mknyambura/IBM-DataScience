# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# <ol>
# <li>Python</li>
# <li>R</li>
# <li>Julia</>li
# <li>Java</li>
# <li>Scala</li>
# <li>C++</li>
# </ol>

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# <ol>
# <li>Pandas</li>
# <li>NumPy</li>
# <li>SciPy</li>
# <li>Matplotlib</li>
# </ol>

# %% [markdown]
# <h1>Data Science Tools</h1>

# %% [markdown]
# <h3>Below are few examples of evaluating arithmetic expressions in Python</h3>

# %%
(3*4)+5

#This is a simple arithmetic expression to multiply then add integers#
# Out:
# 17

# %%
total_minutes = 200

# Get hours with floor division
hours = total_minutes // 60

# Get additional minutes with modulus
minutes = total_minutes % 60

# Create time as a string
time_string = "{}:{}".format(hours, minutes)

print(time_string)

#This will convert 200 minutes into hours by divising by 60
# Out:
# 3:20

# %% [markdown]
# **Objectives:**
# <ul>
# <li>List some common data science languages</li>
# <li>List some common data science libraries</li>
# <li>List some common data science tools</li>
# <li>Introduction to arithmetic expressions</li>
# <li>Write an expression that converts 200 minutes into hours</li>
# </ul>

# %% [markdown]
# <h2>Author</h2>

# %% [markdown]
# Mercy Kariuki
